# %%
import pandas as pd

# %%
df1 = pd.read_csv('file1.csv')
df2 = pd.read_csv('file2.csv')
df3 = pd.read_csv('file3.csv')
df3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
shape1 = df1.shape
shape2 = df2.shape
shape3 = df3.shape

print(shape1, shape2, shape3)
# Out:
# (4008, 11) (996, 11) (7070, 11)

# %%
column_names = [df1.columns, df2.columns, df3.columns]
column_names
# Out:
# [Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#         'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#         'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#        dtype='object'),
#  Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#         'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#         'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#        dtype='object'),
#  Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#         'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#         'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#        dtype='object')]

# %%
#rearange df2 columns
df2 = df2[['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
        'Policy Type', 'Vehicle Class', 'Total Claim Amount']]
df2.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
#rearange df3 columns
df3 = df3[['Customer', 'State', 'Gender', 'Education', 'Customer Lifetime Value',
        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
        'Policy Type', 'Vehicle Class', 'Total Claim Amount']]
df3.columns
# Out:
# Index(['Customer', 'State', 'Gender', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
column_names = [df1.columns, df2.columns, df3.columns]
column_names
# Out:
# [Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#         'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#         'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#        dtype='object'),
#  Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#         'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#         'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#        dtype='object'),
#  Index(['Customer', 'State', 'Gender', 'Education', 'Customer Lifetime Value',
#         'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#         'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#        dtype='object')]

# %%
#standardizing header names
df1.columns = df1.columns.str.lower()
df2.columns = df2.columns.str.lower()
df3.columns = df3.columns.str.lower()
column_names = [df1.columns, df2.columns, df3.columns]
column_names
# Out:
# [Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#         'income', 'monthly premium auto', 'number of open complaints',
#         'policy type', 'vehicle class', 'total claim amount'],
#        dtype='object'),
#  Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#         'income', 'monthly premium auto', 'number of open complaints',
#         'policy type', 'vehicle class', 'total claim amount'],
#        dtype='object'),
#  Index(['customer', 'state', 'gender', 'education', 'customer lifetime value',
#         'income', 'monthly premium auto', 'number of open complaints',
#         'policy type', 'vehicle class', 'total claim amount'],
#        dtype='object')]

# %%
#standardizing "state" column
df1 = df1.rename(columns= {"st":"state"})
df2 = df2.rename(columns= {"st":"state"})
column_names = [df1.columns, df2.columns, df3.columns]
column_names
# Out:
# [Index(['customer', 'state', 'gender', 'education', 'customer lifetime value',
#         'income', 'monthly premium auto', 'number of open complaints',
#         'policy type', 'vehicle class', 'total claim amount'],
#        dtype='object'),
#  Index(['customer', 'state', 'gender', 'education', 'customer lifetime value',
#         'income', 'monthly premium auto', 'number of open complaints',
#         'policy type', 'vehicle class', 'total claim amount'],
#        dtype='object'),
#  Index(['customer', 'state', 'gender', 'education', 'customer lifetime value',
#         'income', 'monthly premium auto', 'number of open complaints',
#         'policy type', 'vehicle class', 'total claim amount'],
#        dtype='object')]

# %%
#concatinating Dframes:
concat_df = pd.concat([df1,df2,df3])
concat_df
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
#which data types are numeric and which categorical:
concat_df.dtypes
# Out:
# customer                      object
# state                         object
# gender                        object
# education                     object
# customer lifetime value       object
# income                       float64
# monthly premium auto         float64
# number of open complaints     object
# policy type                   object
# vehicle class                 object
# total claim amount           float64
# dtype: object

# %%
#droping 'education' and 'number of open complaints' columns
concat_df = concat_df.drop(columns=['education', 'number of open complaints'])
concat_df
# Out:
#      customer       state gender customer lifetime value   income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M                   23406  71941.0
# 7066  PK87824  California      F                 3096.51  21604.0
# 7067  TD14365  California      M                 8163.89      0.0
# 7068  UP19263  California      M                 7524.44  21941.0
# 7069  Y167826  California      M                 2611.84      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
'''Correct the values in the column customer lifetime value. 
They are given as a percent, so multiply them by 100 and change dtype to numerical type.'''

concat_df['customer lifetime value'] = concat_df['customer lifetime value'].fillna('0%')
concat_df['customer lifetime value']
# Out:
# 0                0%
# 1        697953.59%
# 2       1288743.17%
# 3        764586.18%
# 4        536307.65%
#            ...
# 7065          23406
# 7066        3096.51
# 7067        8163.89
# 7068        7524.44
# 7069        2611.84
# Name: customer lifetime value, Length: 12074, dtype: object

# %%
#dropping duplicates
concat_df = concat_df.drop_duplicates()
concat_df
# Out:
#      customer       state gender customer lifetime value   income  \
# 0     RB50392  Washington    NaN                      0%      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M                   23406  71941.0
# 7066  PK87824  California      F                 3096.51  21604.0
# 7067  TD14365  California      M                 8163.89      0.0
# 7068  UP19263  California      M                 7524.44  21941.0
# 7069  Y167826  California      M                 2611.84      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
#Filter out the data for customers who have an income of 0 or less.
negative_income = concat_df[concat_df['income'] <= 0.0]
negative_income
# Out:
#      customer       state gender customer lifetime value  income  \
# 0     RB50392  Washington    NaN                      0%     0.0
# 1     QZ44356     Arizona      F              697953.59%     0.0
# 3     WW63253  California      M              764586.18%     0.0
# 7     CF85061     Arizona      M              721610.03%     0.0
# 10    SX51350  California      M              473899.20%     0.0
# ...       ...         ...    ...                     ...     ...
# 7059  WZ45103  California      F                 5678.05     0.0
# 7061  RX91025  California      M                 19872.3     0.0
# 7062  AC13887  California      M                    4629     0.0
# 7067  TD14365  California      M                 8163.89     0.0
# 7069  Y167826  California      M                 2611.84     0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
concat_df[concat_df['income'] > 0.0]
# Out:
#      customer       state gender customer lifetime value   income  \
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# 5     OC83172      Oregon      F              825629.78%  62902.0
# 6     XZ87318      Oregon      F              538089.86%  55350.0
# 8     DY87989      Oregon      M             2412750.40%  14072.0
# ...       ...         ...    ...                     ...      ...
# 7063  TF56202  California      M                 5032.17  66367.0
# 7064  YM19146  California      F                  4100.4  47761.0
# 7065  LA72316  California      M                   23406  71941.0
# 7066  PK87824  California      F                 3096.51  21604.0
# 7068  UP19263  California      M                 7524.44  21941.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 2                    108.0   Personal Auto   Two-Door Car          566.472247
# ...
